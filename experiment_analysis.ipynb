# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from DoE_module import t as sp_t
import seaborn as sns
sns.set_theme()

def show_matrix(m: pd.DataFrame, cmap="coolwarm", cbar=False, annot=True, **kwargs):
    axim = sns.heatmap(m.rename(columns=dict(Intercep="I")), cmap=cmap, cbar=cbar, annot=annot, **kwargs)
    axim.xaxis.set_ticks_position("top")
    axim.yaxis.set_ticks_position("right")

# %%
M = pd.read_csv("matrix_model.csv")
show_matrix(M)
plt.title("Model matrix")
plt.show()

# %%
R = np.loadtxt("hmax.txt")
plt.bar(x=np.arange(R.size), height=R)
plt.xlabel("Experiment id")
plt.ylabel(r"$h_\mathrm{max}$ [m]")
plt.show()

# %%
def half_effects(M, R):
    Half_effects = np.linalg.solve(M.T @ M, M.T @ R)
    Rel_effects = Half_effects / Half_effects[0]

    beta = 0.95
    alpha = 1-beta
    dof = M.shape[0] - M.shape[1]
    t_student = sp_t.ppf(beta + alpha/2, dof)

    residue = R - M @ Half_effects
    var_exp = residue.T @ residue /(dof)
    D3 = np.linalg.inv(M.T @ M)
    CI = t_student * np.sqrt(np.diag(D3) * var_exp)

    return pd.DataFrame(
        np.vstack((Half_effects.T, CI.T, Rel_effects.T)),
        index=["Half-effects", f"{beta:.0%} CI", "Relative"],
        columns=M.columns
    ).drop(columns=["I"])

# %%
effect_df = half_effects(M, R)

display(
  effect_df
  .T
  .round(3)
  .style.background_gradient(cmap="coolwarm", axis="columns")
  .format(precision=3)
)
# Out:
# <style type="text/css">
# #T_aa315_row0_col0, #T_aa315_row1_col0, #T_aa315_row2_col1, #T_aa315_row3_col0, #T_aa315_row4_col0, #T_aa315_row5_col1, #T_aa315_row6_col0, #T_aa315_row7_col1, #T_aa315_row8_col0, #T_aa315_row9_col1, #T_aa315_row10_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aa315_row0_col1, #T_aa315_row1_col2, #T_aa315_row2_col2, #T_aa315_row3_col1, #T_aa315_row4_col2, #T_aa315_row5_col0, #T_aa315_row6_col2, #T_aa315_row7_col0, #T_aa315_row8_col2, #T_aa315_row9_col0, #T_aa315_row10_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_aa315_row0_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_aa315_row1_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_aa315_row2_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_aa315_row3_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_aa315_row4_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_aa315_row5_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_aa315_row6_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_aa315_row7_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_aa315_row8_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_aa315_row9_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_aa315_row10_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aa315">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa315_level0_col0" class="col_heading level0 col0" >Half-effects</th>
#       <th id="T_aa315_level0_col1" class="col_heading level0 col1" >95% CI</th>
#       <th id="T_aa315_level0_col2" class="col_heading level0 col2" >Relative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa315_level0_row0" class="row_heading level0 row0" >Fr</th>
#       <td id="T_aa315_row0_col0" class="data row0 col0" >6.047</td>
#       <td id="T_aa315_row0_col1" class="data row0 col1" >0.145</td>
#       <td id="T_aa315_row0_col2" class="data row0 col2" >0.374</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row1" class="row_heading level0 row1" >s</th>
#       <td id="T_aa315_row1_col0" class="data row1 col0" >1.933</td>
#       <td id="T_aa315_row1_col1" class="data row1 col1" >0.145</td>
#       <td id="T_aa315_row1_col2" class="data row1 col2" >0.120</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row2" class="row_heading level0 row2" >c</th>
#       <td id="T_aa315_row2_col0" class="data row2 col0" >0.105</td>
#       <td id="T_aa315_row2_col1" class="data row2 col1" >0.145</td>
#       <td id="T_aa315_row2_col2" class="data row2 col2" >0.007</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row3" class="row_heading level0 row3" >o</th>
#       <td id="T_aa315_row3_col0" class="data row3 col0" >3.180</td>
#       <td id="T_aa315_row3_col1" class="data row3 col1" >0.145</td>
#       <td id="T_aa315_row3_col2" class="data row3 col2" >0.197</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row4" class="row_heading level0 row4" >Fr:s</th>
#       <td id="T_aa315_row4_col0" class="data row4 col0" >0.304</td>
#       <td id="T_aa315_row4_col1" class="data row4 col1" >0.145</td>
#       <td id="T_aa315_row4_col2" class="data row4 col2" >0.019</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row5" class="row_heading level0 row5" >Fr:c</th>
#       <td id="T_aa315_row5_col0" class="data row5 col0" >-0.071</td>
#       <td id="T_aa315_row5_col1" class="data row5 col1" >0.145</td>
#       <td id="T_aa315_row5_col2" class="data row5 col2" >-0.004</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row6" class="row_heading level0 row6" >Fr:o</th>
#       <td id="T_aa315_row6_col0" class="data row6 col0" >0.522</td>
#       <td id="T_aa315_row6_col1" class="data row6 col1" >0.145</td>
#       <td id="T_aa315_row6_col2" class="data row6 col2" >0.032</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row7" class="row_heading level0 row7" >s:c</th>
#       <td id="T_aa315_row7_col0" class="data row7 col0" >-0.054</td>
#       <td id="T_aa315_row7_col1" class="data row7 col1" >0.145</td>
#       <td id="T_aa315_row7_col2" class="data row7 col2" >-0.003</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row8" class="row_heading level0 row8" >s:o</th>
#       <td id="T_aa315_row8_col0" class="data row8 col0" >0.469</td>
#       <td id="T_aa315_row8_col1" class="data row8 col1" >0.145</td>
#       <td id="T_aa315_row8_col2" class="data row8 col2" >0.029</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row9" class="row_heading level0 row9" >c:o</th>
#       <td id="T_aa315_row9_col0" class="data row9 col0" >-0.024</td>
#       <td id="T_aa315_row9_col1" class="data row9 col1" >0.145</td>
#       <td id="T_aa315_row9_col2" class="data row9 col2" >-0.001</td>
#     </tr>
#     <tr>
#       <th id="T_aa315_level0_row10" class="row_heading level0 row10" >c:s:o</th>
#       <td id="T_aa315_row10_col0" class="data row10 col0" >0.025</td>
#       <td id="T_aa315_row10_col1" class="data row10 col1" >0.145</td>
#       <td id="T_aa315_row10_col2" class="data row10 col2" >0.002</td>
#     </tr>
#   </tbody>
# </table>

# %%
main_factors = "Fr s c o".split()
effect_matrix = np.zeros((len(main_factors), len(main_factors)), dtype=np.float16)
for i, f1 in enumerate(main_factors):
    for j, f2 in enumerate(main_factors[i:], start=i):
        if f1 == f2:
            f = f1
        else:
            f = f"{f1}:{f2}"
        effect_matrix[i, j] = effect_df[f].iloc[0]
        effect_matrix[j, i] = effect_df[f].iloc[0]

effect_matrix = pd.DataFrame(effect_matrix, columns=main_factors)
vmax = np.abs(effect_matrix).max(axis=None)

show_matrix(effect_matrix, vmin=-vmax, vmax=vmax, cmap="RdBu")
plt.yticks(np.arange(len(main_factors))+1/2, main_factors)
plt.gca().yaxis.tick_left()
plt.show()
